# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

# %%
arr1 = np.array([9,20,28,18,11])
arr2 = np.array([30,1,21,17,28])

# %%
bin_arr1 = [];
bin_arr2 = [];
bin_sol = []
# arr1, arr2를 2진법으로
for i in range(5):
  bin_arr1.append(bin(arr1[i])[2:])# 2진법에서 0b 없애기
  bin_arr2.append(bin(arr2[i])[2:]) 
  if len(bin_arr1[i])<5:            # 5자리 2진법 리스트로 만들기
    bin_arr1[i] = '0'*(5-len(bin_arr1[i]))+ bin_arr1[i]
    bin_arr2[i] = '0'*(5-len(bin_arr2[i]))+ bin_arr2[i]
  bin_sol.append(bin(int(bin_arr1[i], 2) | int(bin_arr2[i], 2))[2:]) #답을 구하기 위해 2진법 or 연산을 한다. 단, or로는 구현이 안되고 | 를 이용
  if len(bin_sol[i])<5:            # 앞자리에 0이 나올 경우를 대비하여 앞에서 했던 것을 또 해준다
    bin_soll[i] = '0'*(5-len(bin_sol[i]))+ bin_sol[i]
print(bin_sol)
# Out:
# ['11111', '10101', '11101', '10011', '11111']

# %%
sol = []
for i in range(5):
  sol.append(bin_sol[i].replace('0', ' '))
  sol[i] = sol[i].replace('1','#')
  print(sol[i])
# Out:
# #####
# # # #
# ### #
# #  ##
# #####

# %% [markdown]
# # 이태민이 다 풀어줌
